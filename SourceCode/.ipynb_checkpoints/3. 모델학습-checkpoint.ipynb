# %%
import pickle

# %%
with open('../../dataset_aihub/raw_data.pickle', 'rb') as f:
    raw_data = pickle.load(f)

# %%
len(raw_data)
# Out:
# 800

# %%
random.shuffle(raw_data)

# %%
import torch

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %%
import numpy as np
import random
from torch.utils.data import Dataset, DataLoader

# %%
class MyDataset(Dataset):
    def __init__(self, seq_list):
        self.X = []
        self.y = []
        for dic in seq_list :
            self.y.append(dic['key'])
            self.X.append(dic['value'])

    def __getitem__(self, index):
        data = self.X[index]
        label = self.y[index]
        return torch.Tensor(np.array(data)), torch.tensor(np.array(int(label)))

    def __len__(self):
        return len(self.X)

# %%
split_ratio = [0.8, 0.1, 0.1]
train_len = int(len(raw_data) * split_ratio[0])
val_len = int(len(raw_data) * split_ratio[1])
test_len = len(raw_data) - train_len - val_len

print('{}, {}, {}'.format(train_len, val_len, test_len))
# Out:
# 640, 80, 80

# %%
from torch.utils.data import random_split

# %%
BATCH_SIZE = 20
EPOCH = 700
NUM_LAYERS = 1      # LSTM model: num_layers

# %%
train_dataset = MyDataset(raw_data)
train_data, valid_data, test_data = random_split(train_dataset, [train_len, val_len, test_len])

train_loader = DataLoader(train_data, batch_size=BATCH_SIZE)
val_loader = DataLoader(valid_data, batch_size=BATCH_SIZE)
test_loader = DataLoader(test_data, batch_size=BATCH_SIZE)

# %%
import torch.nn as nn

# %%
# LSTM
class skeleton_LSTM(nn.Module):
    def __init__(self):
        super(skeleton_LSTM, self).__init__()
        self.lstm1 = nn.LSTM(input_size=len(attention_dot) * 2, hidden_size=128, num_layers=NUM_LAYERS, batch_first=True)
        self.lstm2 = nn.LSTM(input_size=128, hidden_size=256, num_layers=NUM_LAYERS, batch_first=True)
        self.lstm3 = nn.LSTM(input_size=256, hidden_size=512, num_layers=NUM_LAYERS, batch_first=True)
        self.dropout1 = nn.Dropout(0.1)
        self.lstm4 = nn.LSTM(input_size=512, hidden_size=256, num_layers=NUM_LAYERS, batch_first=True)
        self.lstm5 = nn.LSTM(input_size=256, hidden_size=128, num_layers=NUM_LAYERS, batch_first=True)
        self.lstm6 = nn.LSTM(input_size=128, hidden_size=64, num_layers=NUM_LAYERS, batch_first=True)
        self.dropout2 = nn.Dropout(0.1)
        self.lstm7 = nn.LSTM(input_size=64, hidden_size=32, num_layers=NUM_LAYERS, batch_first=True)
        self.fc = nn.Linear(32,2)

    def forward(self, x) :
        x, _ = self.lstm1(x)
        x, _ = self.lstm2(x)
        x, _ = self.lstm3(x)
        x = self.dropout1(x)
        x, _ = self.lstm4(x)
        x, _ = self.lstm5(x)
        x, _ = self.lstm6(x)
        x = self.dropout2(x)
        x, _ = self.lstm7(x)
        x = self.fc(x[:,-1,:]) # x[배치 크기, 시퀀스 길이, 은닉 상태 크기], [:, -1, :] -> 마지막 시간 단계만 선택

        return x

# %%
from torch.optim import Adam

# %%
# 모델 초기화

def init_model():
    global net, loss_fn, optim
    plt.rc('font', size = 10)
    net = skeleton_LSTM().to(device)
    loss_fn = nn.CrossEntropyLoss()
    optim = Adam(net.parameters(), lr=0.0001)

# epoch 카운터 초기화
def init_epoch():
    global epoch_cnt
    epoch_cnt = 0

# 모든 Log를 초기화
def init_log():
    global log_stack, iter_log, tloss_log, tacc_log, vloss_log, vacc_log, time_log
    plt.rc('font', size = 10)
    iter_log, tloss_log, tacc_log, vloss_log, vacc_log = [], [], [], [], []
    time_log, log_stack = [], []

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def record_train_log(_tloss, _tacc, _time):
    # Train Log 기록
    time_log.append(_time)
    tloss_log.append(_tloss)
    tacc_log.append(_tacc)
    iter_log.append(epoch_cnt)

def record_valid_log(_vloss, _vacc):
    # Validation Log 기록
    vloss_log.append(_vloss)
    vacc_log.append(_vacc)

def last(log_list):
    # last 안의 마지막 숫자를 반환(print_log 함수에서 사용)
    if len(log_list) > 0:
        return log_list[len(log_list) - 1]
    else:
        return -1

def print_log():
    # 학습 추이 출력 : 소숫점 3자리까지
    train_loss = round(float(last(tloss_log)), 3)
    train_acc = round(float(last(tacc_log)), 3)
    val_loss = round(float(last(vloss_log)), 3)
    val_acc = round(float(last(vacc_log)), 3)
    time_spent = round(float(last(time_log)), 3)

    log_str = 'Epoch: {:3} | T_Loss {:5} | T_Acc {:5} | V_Loss {:5} | V_Acc {:5} | {:5}'.format(last(iter_log), train_loss, train_acc, val_loss, val_acc, time_spent)

    log_stack.append(log_str)
    
    # 학습 추이 그래프 출력
    hist_fig, loss_axis = plt.subplots(figsize=(10, 3), dpi=99)
    hist_fig.patch.set_facecolor('white')

    # Loss Line 구성
    loss_t_line = plt.plot(iter_log, tloss_log, label='Train_Loss', color='red', marker='o')
    loss_v_line = plt.plot(iter_log, vloss_log, label='Valid_Loss', color='blue', marker='s')
    loss_axis.set_xlabel('epoch')
    loss_axis.set_ylabel('loss')

    # Acc, Line 구성
    acc_axis = loss_axis.twinx()
    acc_t_line = acc_axis.plot(iter_log, tacc_log, label='Train_Acc', color='red', marker='+')
    acc_v_line = acc_axis.plot(iter_log, vacc_log, label='Valid_Acc', color='blue', marker='x')
    acc_axis.set_ylabel('accuracy')

    # 그래프 출력
    hist_lines = loss_t_line + loss_v_line + acc_t_line + acc_v_line
    loss_axis.legend(hist_lines, [l.get_label() for l in hist_lines])
    loss_axis.grid()
    plt.title('Learning history until epoch {}'.format(last(iter_log)))
    plt.draw()

    # 텍스트 로그 출력
    clear_output(wait=True)
    plt.show()
    for idx in reversed(range(len(log_stack))):
        print(log_stack[idx])

# %%
import gc

# %%
def clear_memory():
    if device != 'cpu':
        empty_cache()
    gc.collect()

# %%
# 학습 알고리즘
def epoch(data_loader, mode = 'train'):
    global epoch_cnt

    # 사용되는 변수 초기화
    iter_loss, iter_acc, last_grad_performed = [], [], False

    # 1 iteration 학습 알고리즘(for문을 나오면 1 epoch 완료)
    for _data, _label in data_loader:
        data, label = _data.to(device), _label.type(torch.LongTensor).to(device)

        # 1. Feed-forward
        if mode == 'train':
            net.train()
        else:
            # 학습때만 쓰이는 Dropout, Batch Mormalization을 미사용
            net.eval()

        result = net(data) # 1 Batch에 대한 결과가 모든 Class에 대한 확률값으로
        _, out = torch.max(result, 1) # result에서 최대 확률값을 기준으로 예측 class 도출( _ : 값 부분은 필요 없음, out : index 중 가장 큰 하나의 데이터)

        # 2. Loss 계산
        loss = loss_fn(result, label) # GT 와 Label 비교하여 Loss 산정
        iter_loss.append(loss.item()) # 학습 추이를 위하여 Loss를 기록

        # 3. 역전파 학습 후 Gradient Descent
        if mode == 'train':
            optim.zero_grad() # 미분을 통해 얻은 기울기를 초기화 for 다음 epoch
            loss.backward() # 역전파 학습
            optim.step() # Gradient Descent 수행
            last_grad_performed = True # for문을 나가면 epoch 카운터 += 1

        # 4. 정확도 계산
        acc_partial = (out == label).float().sum() # GT == Label 인 개수
        acc_partial = acc_partial / len(label) # ( TP / (TP + TM)) 해서 정확도 산출
        iter_acc.append(acc_partial.item()) # 학습 추이를 위하여 Acc. 기록

    # 역전파 학습 후 Epoch 카운터 += 1
    if last_grad_performed:
        epoch_cnt += 1

    clear_memory()

    # loss와 acc의 평균값 for 학습추이 그래프, 모든 GT와 Label 값 for 컨퓨전 매트릭스
    return np.average(iter_loss), np.average(iter_acc)

def epoch_not_finished():
    # 에폭이 끝남을 알림
    return epoch_cnt < maximum_epoch

# %%
import time
from torch.cuda import memory_allocated, empty_cache
from IPython.display import Image, clear_output
start_dot = 11      # mp.solutions.pose 시작 포인트 (0: 얼굴부터 발목까지, 11: 어깨부터 발목까지)
attention_dot = [n for n in range(start_dot, 29)]

# %%
# Training initialization
init_model()
init_epoch()
init_log()
maximum_epoch = EPOCH

# Training iteration

while epoch_not_finished():
    start_time = time.time()

    tloss, tacc = epoch(train_loader, mode = 'train')

    end_time = time.time()
    time_taken = end_time - start_time
    record_train_log(tloss, tacc, time_taken)

    with torch.no_grad():
        vloss, vacc = epoch(val_loader, mode = 'val')
        record_valid_log(vloss, vacc)

    print_log()

print('\n Training completed!')
# Out:
# Epoch: 396 | T_Loss 0.025 | T_Acc 0.997 | V_Loss  1.33 | V_Acc 0.725 | 4.276
# Epoch: 395 | T_Loss 0.028 | T_Acc 0.995 | V_Loss 1.289 | V_Acc 0.725 | 4.038
# Epoch: 394 | T_Loss 0.036 | T_Acc 0.994 | V_Loss 1.262 | V_Acc 0.725 | 4.143
# Epoch: 393 | T_Loss 0.029 | T_Acc 0.995 | V_Loss 1.304 | V_Acc 0.712 | 4.086
# Epoch: 392 | T_Loss 0.029 | T_Acc 0.997 | V_Loss 1.234 | V_Acc 0.712 | 3.981
# Epoch: 391 | T_Loss 0.031 | T_Acc 0.995 | V_Loss 1.214 | V_Acc 0.712 | 4.066
# Epoch: 390 | T_Loss 0.038 | T_Acc 0.994 | V_Loss 1.147 | V_Acc   0.7 | 3.935
# Epoch: 389 | T_Loss 0.052 | T_Acc 0.989 | V_Loss 1.153 | V_Acc   0.7 | 3.939
# Epoch: 388 | T_Loss 0.088 | T_Acc 0.972 | V_Loss 1.187 | V_Acc 0.687 | 3.902
# Epoch: 387 | T_Loss 0.096 | T_Acc 0.964 | V_Loss 1.156 | V_Acc   0.7 | 4.052
# Epoch: 386 | T_Loss 0.096 | T_Acc 0.973 | V_Loss 1.063 | V_Acc 0.688 |  4.04
# Epoch: 385 | T_Loss 0.217 | T_Acc 0.919 | V_Loss 1.029 | V_Acc 0.712 | 3.875
# Epoch: 384 | T_Loss 0.162 | T_Acc 0.941 | V_Loss 1.486 | V_Acc 0.675 | 3.785
# Epoch: 383 | T_Loss  0.08 | T_Acc 0.978 | V_Loss 1.346 | V_Acc   0.7 | 4.058
# Epoch: 382 | T_Loss 0.034 | T_Acc 0.992 | V_Loss 1.296 | V_Acc 0.725 | 3.893
# Epoch: 381 | T_Loss 0.039 | T_Acc 0.989 | V_Loss 1.284 | V_Acc 0.688 | 4.122
# Epoch: 380 | T_Loss 0.031 | T_Acc 0.992 | V_Loss 1.242 | V_Acc 0.712 | 3.881
# Epoch: 379 | T_Loss 0.058 | T_Acc 0.978 | V_Loss 1.226 | V_Acc 0.725 | 4.095
# Epoch: 378 | T_Loss 0.047 | T_Acc 0.991 | V_Loss 1.209 | V_Acc   0.7 | 3.952
# Epoch: 377 | T_Loss 0.071 | T_Acc 0.973 | V_Loss 1.163 | V_Acc 0.712 | 4.076
# Epoch: 376 | T_Loss 0.127 | T_Acc 0.953 | V_Loss 1.135 | V_Acc 0.725 | 3.989
# Epoch: 375 | T_Loss 0.156 | T_Acc 0.952 | V_Loss 1.098 | V_Acc   0.7 |  3.88
# Epoch: 374 | T_Loss 0.043 | T_Acc 0.986 | V_Loss 1.313 | V_Acc 0.662 | 4.287
# Epoch: 373 | T_Loss 0.039 | T_Acc 0.991 | V_Loss 1.332 | V_Acc 0.688 | 3.895
# Epoch: 372 | T_Loss 0.036 | T_Acc 0.991 | V_Loss 1.227 | V_Acc   0.7 | 3.887
# Epoch: 371 | T_Loss 0.042 | T_Acc 0.991 | V_Loss 1.147 | V_Acc   0.7 | 3.868
# Epoch: 370 | T_Loss 0.049 | T_Acc 0.989 | V_Loss 1.109 | V_Acc   0.7 | 3.817
# Epoch: 369 | T_Loss 0.093 | T_Acc 0.967 | V_Loss 1.041 | V_Acc 0.725 | 3.961
# Epoch: 368 | T_Loss 0.139 | T_Acc 0.941 | V_Loss 0.965 | V_Acc 0.688 | 3.795
# Epoch: 367 | T_Loss 0.233 | T_Acc 0.903 | V_Loss 0.984 | V_Acc 0.675 | 4.026
# Epoch: 366 | T_Loss 0.189 | T_Acc  0.93 | V_Loss 0.936 | V_Acc 0.725 | 3.765
# Epoch: 365 | T_Loss 0.216 | T_Acc 0.923 | V_Loss 1.008 | V_Acc 0.737 | 4.327
# Epoch: 364 | T_Loss 0.134 | T_Acc 0.952 | V_Loss 1.089 | V_Acc 0.713 |   4.0
# Epoch: 363 | T_Loss 0.077 | T_Acc 0.977 | V_Loss 1.105 | V_Acc 0.737 | 3.882
# Epoch: 362 | T_Loss 0.079 | T_Acc 0.977 | V_Loss 1.083 | V_Acc 0.737 | 4.032
# Epoch: 361 | T_Loss   0.1 | T_Acc 0.972 | V_Loss 0.989 | V_Acc 0.737 | 3.987
# Epoch: 360 | T_Loss 0.114 | T_Acc 0.969 | V_Loss 0.915 | V_Acc 0.763 | 4.213
# Epoch: 359 | T_Loss 0.182 | T_Acc 0.939 | V_Loss  0.77 | V_Acc   0.8 | 4.494
# Epoch: 358 | T_Loss 0.246 | T_Acc  0.92 | V_Loss 0.676 | V_Acc 0.775 | 3.984
# Epoch: 357 | T_Loss 0.347 | T_Acc 0.897 | V_Loss 0.667 | V_Acc  0.75 | 4.286
# Epoch: 356 | T_Loss 0.619 | T_Acc 0.811 | V_Loss 0.682 | V_Acc 0.725 | 4.652
# Epoch: 355 | T_Loss 0.222 | T_Acc 0.936 | V_Loss 1.853 | V_Acc 0.662 | 3.863
# Epoch: 354 | T_Loss 0.031 | T_Acc 0.992 | V_Loss 1.374 | V_Acc 0.737 |  4.13
# Epoch: 353 | T_Loss 0.026 | T_Acc 0.994 | V_Loss 1.499 | V_Acc   0.7 | 3.961
# Epoch: 352 | T_Loss 0.025 | T_Acc 0.995 | V_Loss 1.482 | V_Acc   0.7 |  4.34
# Epoch: 351 | T_Loss 0.026 | T_Acc 0.995 | V_Loss 1.457 | V_Acc   0.7 | 4.345
# Epoch: 350 | T_Loss 0.029 | T_Acc 0.994 | V_Loss  1.44 | V_Acc 0.713 | 4.433
# Epoch: 349 | T_Loss 0.031 | T_Acc 0.995 | V_Loss 1.454 | V_Acc 0.725 | 3.799
# Epoch: 348 | T_Loss 0.033 | T_Acc 0.989 | V_Loss 1.467 | V_Acc   0.7 | 3.992
# Epoch: 347 | T_Loss 0.031 | T_Acc 0.992 | V_Loss 1.399 | V_Acc 0.712 | 4.008
# Epoch: 346 | T_Loss 0.033 | T_Acc 0.994 | V_Loss 1.375 | V_Acc 0.712 | 3.749
# Epoch: 345 | T_Loss  0.04 | T_Acc 0.989 | V_Loss 1.298 | V_Acc   0.7 | 3.788
# Epoch: 344 | T_Loss  0.05 | T_Acc 0.986 | V_Loss 1.364 | V_Acc   0.7 | 3.771
# Epoch: 343 | T_Loss 0.064 | T_Acc 0.983 | V_Loss 1.295 | V_Acc 0.712 | 3.766
# Epoch: 342 | T_Loss 0.053 | T_Acc 0.986 | V_Loss   1.2 | V_Acc 0.725 | 3.851
# Epoch: 341 | T_Loss 0.073 | T_Acc 0.983 | V_Loss 1.191 | V_Acc  0.75 | 3.829
# Epoch: 340 | T_Loss 0.092 | T_Acc 0.962 | V_Loss 1.142 | V_Acc 0.725 | 3.851
# Epoch: 339 | T_Loss 0.194 | T_Acc 0.923 | V_Loss  1.25 | V_Acc   0.7 | 3.991
# Epoch: 338 | T_Loss 0.177 | T_Acc 0.944 | V_Loss 1.316 | V_Acc  0.65 |  3.85
# Epoch: 337 | T_Loss 0.145 | T_Acc 0.953 | V_Loss 1.052 | V_Acc 0.762 | 3.795
# Epoch: 336 | T_Loss 0.077 | T_Acc 0.975 | V_Loss 1.364 | V_Acc 0.675 |  3.91
# Epoch: 335 | T_Loss 0.033 | T_Acc 0.991 | V_Loss 1.439 | V_Acc 0.712 | 3.783
# Epoch: 334 | T_Loss 0.038 | T_Acc 0.991 | V_Loss 1.393 | V_Acc   0.7 | 3.915
# Epoch: 333 | T_Loss 0.033 | T_Acc 0.992 | V_Loss 1.417 | V_Acc 0.725 | 4.033
# Epoch: 332 | T_Loss 0.036 | T_Acc 0.992 | V_Loss 1.387 | V_Acc 0.725 | 3.926
# Epoch: 331 | T_Loss 0.036 | T_Acc 0.991 | V_Loss 1.362 | V_Acc 0.725 | 3.965
# Epoch: 330 | T_Loss 0.039 | T_Acc 0.991 | V_Loss 1.338 | V_Acc 0.713 | 3.977
# Epoch: 329 | T_Loss  0.04 | T_Acc 0.983 | V_Loss 1.327 | V_Acc 0.713 | 4.066
# Epoch: 328 | T_Loss 0.044 | T_Acc 0.986 | V_Loss 1.261 | V_Acc 0.725 | 3.761
# Epoch: 327 | T_Loss 0.055 | T_Acc 0.981 | V_Loss  1.26 | V_Acc   0.7 | 3.965
# Epoch: 326 | T_Loss 0.056 | T_Acc 0.986 | V_Loss 1.227 | V_Acc   0.7 |  3.98
# Epoch: 325 | T_Loss 0.062 | T_Acc 0.984 | V_Loss 1.228 | V_Acc 0.712 | 3.848
# Epoch: 324 | T_Loss 0.079 | T_Acc  0.97 | V_Loss 1.206 | V_Acc 0.712 | 3.946
# Epoch: 323 | T_Loss  0.09 | T_Acc 0.966 | V_Loss 1.074 | V_Acc 0.725 | 3.888
# Epoch: 322 | T_Loss 0.125 | T_Acc 0.953 | V_Loss 0.989 | V_Acc 0.737 | 3.885
# Epoch: 321 | T_Loss 0.157 | T_Acc 0.941 | V_Loss 1.153 | V_Acc   0.7 | 3.949
# Epoch: 320 | T_Loss 0.201 | T_Acc 0.934 | V_Loss 1.087 | V_Acc 0.725 |  4.12
# Epoch: 319 | T_Loss 0.311 | T_Acc 0.883 | V_Loss 0.988 | V_Acc 0.712 | 4.195
# Epoch: 318 | T_Loss 0.328 | T_Acc 0.889 | V_Loss  1.13 | V_Acc 0.725 | 4.479
# Epoch: 317 | T_Loss 0.073 | T_Acc 0.967 | V_Loss 1.237 | V_Acc 0.725 | 4.357
# Epoch: 316 | T_Loss 0.038 | T_Acc 0.978 | V_Loss 1.384 | V_Acc 0.737 | 3.987
# Epoch: 315 | T_Loss  0.04 | T_Acc 0.977 | V_Loss 1.338 | V_Acc 0.737 | 4.365
# Epoch: 314 | T_Loss 0.039 | T_Acc 0.975 | V_Loss 1.352 | V_Acc 0.737 |  4.36
# Epoch: 313 | T_Loss 0.043 | T_Acc 0.975 | V_Loss   1.3 | V_Acc 0.737 | 4.338
# Epoch: 312 | T_Loss 0.044 | T_Acc 0.975 | V_Loss 1.343 | V_Acc 0.725 | 4.329
# Epoch: 311 | T_Loss 0.049 | T_Acc 0.973 | V_Loss  1.29 | V_Acc 0.737 | 4.161
# Epoch: 310 | T_Loss 0.053 | T_Acc 0.975 | V_Loss 1.284 | V_Acc 0.712 |  4.08
# Epoch: 309 | T_Loss 0.055 | T_Acc 0.972 | V_Loss 1.241 | V_Acc 0.712 |  3.92
# Epoch: 308 | T_Loss 0.061 | T_Acc  0.97 | V_Loss 1.193 | V_Acc 0.725 | 4.173
# Epoch: 307 | T_Loss 0.061 | T_Acc 0.973 | V_Loss 1.086 | V_Acc 0.737 |  4.09
# Epoch: 306 | T_Loss  0.08 | T_Acc 0.962 | V_Loss 1.077 | V_Acc 0.762 | 3.988
# Epoch: 305 | T_Loss 0.088 | T_Acc 0.966 | V_Loss 1.132 | V_Acc   0.7 | 3.992
# Epoch: 304 | T_Loss 0.116 | T_Acc 0.955 | V_Loss 1.138 | V_Acc 0.725 | 4.115
# Epoch: 303 | T_Loss 0.228 | T_Acc 0.927 | V_Loss 0.878 | V_Acc 0.737 | 3.893
# Epoch: 302 | T_Loss 0.089 | T_Acc 0.964 | V_Loss 1.125 | V_Acc 0.713 | 3.982
# Epoch: 301 | T_Loss  0.12 | T_Acc 0.947 | V_Loss 1.112 | V_Acc 0.725 | 3.924
# Epoch: 300 | T_Loss 0.125 | T_Acc 0.953 | V_Loss 0.917 | V_Acc  0.75 | 3.972
# Epoch: 299 | T_Loss 0.126 | T_Acc  0.95 | V_Loss 0.985 | V_Acc 0.737 | 3.894
# Epoch: 298 | T_Loss  0.12 | T_Acc 0.955 | V_Loss 0.965 | V_Acc 0.763 | 4.392
# Epoch: 297 | T_Loss   0.1 | T_Acc 0.959 | V_Loss 0.948 | V_Acc  0.75 |  4.17
# Epoch: 296 | T_Loss  0.15 | T_Acc 0.944 | V_Loss 1.025 | V_Acc 0.737 | 4.148
# Epoch: 295 | T_Loss 0.224 | T_Acc 0.931 | V_Loss 1.147 | V_Acc 0.737 | 4.275
# Epoch: 294 | T_Loss 0.119 | T_Acc 0.956 | V_Loss 1.092 | V_Acc 0.737 | 4.074
# Epoch: 293 | T_Loss 0.085 | T_Acc 0.969 | V_Loss 1.101 | V_Acc  0.75 |  4.04
# Epoch: 292 | T_Loss 0.087 | T_Acc 0.969 | V_Loss 1.065 | V_Acc  0.75 | 4.143
# Epoch: 291 | T_Loss 0.101 | T_Acc 0.962 | V_Loss  1.02 | V_Acc 0.737 | 4.453
# Epoch: 290 | T_Loss 0.097 | T_Acc 0.961 | V_Loss 1.068 | V_Acc 0.725 | 4.204
# Epoch: 289 | T_Loss 0.115 | T_Acc 0.959 | V_Loss 0.906 | V_Acc 0.738 |  4.43
# Epoch: 288 | T_Loss 0.175 | T_Acc 0.933 | V_Loss 1.025 | V_Acc 0.713 | 4.457
# Epoch: 287 | T_Loss 0.372 | T_Acc  0.87 | V_Loss 1.023 | V_Acc 0.712 |  4.83
# Epoch: 286 | T_Loss  0.26 | T_Acc 0.912 | V_Loss 0.994 | V_Acc 0.688 | 13.563
# Epoch: 285 | T_Loss 0.175 | T_Acc 0.934 | V_Loss 1.138 | V_Acc 0.687 |  5.22
# Epoch: 284 | T_Loss 0.159 | T_Acc 0.945 | V_Loss 0.979 | V_Acc 0.763 | 5.749
# Epoch: 283 | T_Loss 0.066 | T_Acc 0.972 | V_Loss 1.112 | V_Acc 0.737 |  13.9
# Epoch: 282 | T_Loss 0.068 | T_Acc 0.972 | V_Loss 1.111 | V_Acc 0.737 | 7.267
# Epoch: 281 | T_Loss 0.068 | T_Acc 0.973 | V_Loss 1.262 | V_Acc 0.713 | 4.891
# Epoch: 280 | T_Loss 0.089 | T_Acc 0.969 | V_Loss 1.184 | V_Acc 0.725 | 4.866
# Epoch: 279 | T_Loss  0.12 | T_Acc 0.958 | V_Loss 1.027 | V_Acc 0.775 | 5.679
# Epoch: 278 | T_Loss 0.095 | T_Acc 0.964 | V_Loss 0.972 | V_Acc  0.75 | 5.611
# Epoch: 277 | T_Loss 0.096 | T_Acc 0.962 | V_Loss 1.151 | V_Acc   0.7 | 5.173
# Epoch: 276 | T_Loss 0.105 | T_Acc 0.962 | V_Loss 1.101 | V_Acc   0.7 | 5.059
# Epoch: 275 | T_Loss 0.089 | T_Acc 0.969 | V_Loss 0.963 | V_Acc  0.75 | 4.507
# Epoch: 274 | T_Loss 0.101 | T_Acc 0.962 | V_Loss 0.993 | V_Acc 0.737 | 4.026
# Epoch: 273 | T_Loss 0.124 | T_Acc 0.955 | V_Loss 1.104 | V_Acc   0.7 | 4.064
# Epoch: 272 | T_Loss 0.198 | T_Acc 0.931 | V_Loss 0.875 | V_Acc 0.737 | 4.187
# Epoch: 271 | T_Loss 0.269 | T_Acc 0.905 | V_Loss 0.978 | V_Acc   0.7 | 4.186
# Epoch: 270 | T_Loss 0.133 | T_Acc 0.956 | V_Loss 0.974 | V_Acc 0.725 | 3.996
# Epoch: 269 | T_Loss 0.122 | T_Acc 0.955 | V_Loss  1.07 | V_Acc 0.725 | 3.934
# Epoch: 268 | T_Loss 0.154 | T_Acc 0.941 | V_Loss 0.936 | V_Acc 0.725 | 4.043
# Epoch: 267 | T_Loss  0.19 | T_Acc  0.93 | V_Loss 1.094 | V_Acc   0.7 |  4.09
# Epoch: 266 | T_Loss 0.225 | T_Acc 0.916 | V_Loss 0.932 | V_Acc 0.725 | 3.961
# Epoch: 265 | T_Loss 0.143 | T_Acc 0.944 | V_Loss 0.893 | V_Acc  0.75 | 4.187
# Epoch: 264 | T_Loss  0.13 | T_Acc 0.948 | V_Loss 1.075 | V_Acc   0.7 | 4.089
# Epoch: 263 | T_Loss 0.158 | T_Acc 0.936 | V_Loss 0.968 | V_Acc 0.725 | 3.843
# Epoch: 262 | T_Loss 0.126 | T_Acc 0.953 | V_Loss  1.04 | V_Acc   0.7 | 3.929
# Epoch: 261 | T_Loss 0.131 | T_Acc 0.959 | V_Loss 0.951 | V_Acc 0.725 | 3.962
# Epoch: 260 | T_Loss 0.173 | T_Acc 0.944 | V_Loss 0.885 | V_Acc 0.737 | 4.002
# Epoch: 259 | T_Loss 0.196 | T_Acc 0.936 | V_Loss 0.946 | V_Acc 0.763 | 4.056
# Epoch: 258 | T_Loss 0.201 | T_Acc 0.922 | V_Loss 0.855 | V_Acc 0.788 | 4.142
# Epoch: 257 | T_Loss 0.139 | T_Acc 0.952 | V_Loss 1.136 | V_Acc 0.713 | 4.151
# Epoch: 256 | T_Loss 0.121 | T_Acc 0.956 | V_Loss 1.049 | V_Acc 0.737 | 4.217
# Epoch: 255 | T_Loss 0.126 | T_Acc  0.95 | V_Loss 1.124 | V_Acc   0.7 |  4.03
# Epoch: 254 | T_Loss 0.132 | T_Acc 0.952 | V_Loss 0.978 | V_Acc 0.737 | 3.963
# Epoch: 253 | T_Loss 0.122 | T_Acc 0.958 | V_Loss 1.001 | V_Acc 0.725 | 3.905
# Epoch: 252 | T_Loss 0.137 | T_Acc  0.95 | V_Loss 0.918 | V_Acc 0.737 | 4.054
# Epoch: 251 | T_Loss 0.154 | T_Acc 0.944 | V_Loss 0.821 | V_Acc  0.75 | 4.286
# Epoch: 250 | T_Loss 0.171 | T_Acc 0.942 | V_Loss 0.737 | V_Acc 0.788 | 3.858
# Epoch: 249 | T_Loss 0.251 | T_Acc 0.906 | V_Loss 0.649 | V_Acc 0.813 | 4.124
# Epoch: 248 | T_Loss 0.249 | T_Acc 0.916 | V_Loss 0.884 | V_Acc  0.75 | 3.963
# Epoch: 247 | T_Loss 0.321 | T_Acc 0.873 | V_Loss 0.551 | V_Acc 0.775 | 4.359
# Epoch: 246 | T_Loss 0.559 | T_Acc 0.792 | V_Loss 0.639 | V_Acc 0.737 | 4.242
# Epoch: 245 | T_Loss 0.441 | T_Acc 0.864 | V_Loss 1.004 | V_Acc  0.65 | 4.195
# Epoch: 244 | T_Loss 0.145 | T_Acc 0.953 | V_Loss 0.961 | V_Acc  0.75 | 4.271
# Epoch: 243 | T_Loss 0.125 | T_Acc 0.952 | V_Loss 0.904 | V_Acc 0.787 | 4.159
# Epoch: 242 | T_Loss 0.129 | T_Acc 0.953 | V_Loss 0.968 | V_Acc  0.75 | 4.198
# Epoch: 241 | T_Loss 0.143 | T_Acc 0.944 | V_Loss  0.94 | V_Acc  0.75 | 4.095
# Epoch: 240 | T_Loss 0.182 | T_Acc 0.934 | V_Loss 0.933 | V_Acc 0.737 | 4.104
# Epoch: 239 | T_Loss 0.136 | T_Acc 0.952 | V_Loss 0.927 | V_Acc  0.75 | 4.063
# Epoch: 238 | T_Loss 0.128 | T_Acc 0.955 | V_Loss 0.919 | V_Acc 0.763 | 4.154
# Epoch: 237 | T_Loss 0.162 | T_Acc 0.944 | V_Loss 0.859 | V_Acc 0.763 | 4.277
# Epoch: 236 | T_Loss 0.149 | T_Acc 0.945 | V_Loss 0.887 | V_Acc 0.737 | 4.124
# Epoch: 235 | T_Loss 0.158 | T_Acc 0.953 | V_Loss 0.854 | V_Acc 0.763 | 4.452
# Epoch: 234 | T_Loss 0.136 | T_Acc 0.956 | V_Loss 0.897 | V_Acc  0.75 | 4.126
# Epoch: 233 | T_Loss 0.144 | T_Acc 0.953 | V_Loss 0.844 | V_Acc 0.737 | 4.111
# Epoch: 232 | T_Loss 0.183 | T_Acc 0.937 | V_Loss 0.865 | V_Acc 0.763 | 4.152
# Epoch: 231 | T_Loss 0.163 | T_Acc 0.947 | V_Loss 0.821 | V_Acc 0.763 | 4.303
# Epoch: 230 | T_Loss 0.185 | T_Acc 0.933 | V_Loss 0.784 | V_Acc 0.763 | 3.837
# Epoch: 229 | T_Loss 0.231 | T_Acc 0.919 | V_Loss 0.836 | V_Acc 0.737 | 3.768
# Epoch: 228 | T_Loss 0.203 | T_Acc 0.919 | V_Loss 1.137 | V_Acc 0.675 | 3.839
# Epoch: 227 | T_Loss 0.178 | T_Acc 0.941 | V_Loss 0.959 | V_Acc 0.725 | 4.029
# Epoch: 226 | T_Loss 0.157 | T_Acc 0.942 | V_Loss 0.875 | V_Acc 0.725 | 3.922
# Epoch: 225 | T_Loss 0.169 | T_Acc 0.941 | V_Loss 0.812 | V_Acc  0.75 | 4.201
# Epoch: 224 | T_Loss 0.179 | T_Acc 0.942 | V_Loss  0.88 | V_Acc 0.725 |  3.86
# Epoch: 223 | T_Loss 0.185 | T_Acc 0.933 | V_Loss 0.841 | V_Acc 0.725 | 3.755
# Epoch: 222 | T_Loss 0.208 | T_Acc 0.923 | V_Loss 0.787 | V_Acc 0.713 | 3.751
# Epoch: 221 | T_Loss 0.249 | T_Acc 0.903 | V_Loss 0.727 | V_Acc  0.75 | 3.968
# Epoch: 220 | T_Loss 0.293 | T_Acc 0.883 | V_Loss 0.653 | V_Acc  0.75 | 3.964
# Epoch: 219 | T_Loss 0.373 | T_Acc 0.866 | V_Loss 0.831 | V_Acc   0.7 | 4.015
# Epoch: 218 | T_Loss 0.273 | T_Acc 0.902 | V_Loss 0.681 | V_Acc 0.737 | 3.979
# Epoch: 217 | T_Loss 0.212 | T_Acc 0.923 | V_Loss 0.632 | V_Acc 0.788 | 4.009
# Epoch: 216 | T_Loss 0.222 | T_Acc 0.916 | V_Loss 0.667 | V_Acc   0.8 | 3.986
# Epoch: 215 | T_Loss  0.22 | T_Acc 0.923 | V_Loss  0.67 | V_Acc 0.763 |  3.85
# Epoch: 214 | T_Loss 0.237 | T_Acc 0.914 | V_Loss 0.658 | V_Acc 0.788 | 3.989
# Epoch: 213 | T_Loss 0.226 | T_Acc 0.928 | V_Loss 0.672 | V_Acc 0.737 | 3.744
# Epoch: 212 | T_Loss 0.249 | T_Acc 0.912 | V_Loss 0.679 | V_Acc 0.775 | 3.917
# Epoch: 211 | T_Loss 0.274 | T_Acc 0.894 | V_Loss 0.644 | V_Acc  0.75 | 4.116
# Epoch: 210 | T_Loss  0.31 | T_Acc 0.883 | V_Loss 0.577 | V_Acc   0.8 | 3.846
# Epoch: 209 | T_Loss 0.354 | T_Acc  0.88 | V_Loss 0.577 | V_Acc  0.75 | 3.853
# Epoch: 208 | T_Loss 0.232 | T_Acc 0.916 | V_Loss 0.738 | V_Acc 0.775 | 3.845
# Epoch: 207 | T_Loss 0.229 | T_Acc 0.919 | V_Loss 0.741 | V_Acc  0.75 | 3.837
# Epoch: 206 | T_Loss 0.256 | T_Acc 0.898 | V_Loss 0.695 | V_Acc 0.788 | 3.719
# Epoch: 205 | T_Loss 0.236 | T_Acc 0.917 | V_Loss 0.689 | V_Acc   0.8 | 3.941
# Epoch: 204 | T_Loss 0.294 | T_Acc  0.88 | V_Loss 0.671 | V_Acc   0.8 | 3.814
# Epoch: 203 | T_Loss 0.272 | T_Acc 0.889 | V_Loss 0.742 | V_Acc 0.737 | 4.087
# Epoch: 202 | T_Loss 0.258 | T_Acc 0.906 | V_Loss 0.768 | V_Acc 0.737 | 3.889
# Epoch: 201 | T_Loss  0.33 | T_Acc 0.872 | V_Loss 0.577 | V_Acc 0.812 | 3.991
# Epoch: 200 | T_Loss 0.271 | T_Acc 0.905 | V_Loss  0.76 | V_Acc 0.788 | 3.765
# Epoch: 199 | T_Loss 0.247 | T_Acc 0.911 | V_Loss   0.6 | V_Acc 0.825 | 3.767
# Epoch: 198 | T_Loss 0.262 | T_Acc 0.906 | V_Loss 0.682 | V_Acc   0.8 |  3.79
# Epoch: 197 | T_Loss 0.245 | T_Acc 0.914 | V_Loss 0.712 | V_Acc 0.763 | 3.902
# Epoch: 196 | T_Loss  0.29 | T_Acc 0.887 | V_Loss 0.685 | V_Acc 0.813 | 3.993
# Epoch: 195 | T_Loss 0.289 | T_Acc 0.891 | V_Loss 0.618 | V_Acc 0.788 |   4.0
# Epoch: 194 | T_Loss 0.273 | T_Acc   0.9 | V_Loss 0.708 | V_Acc  0.75 | 4.039
# Epoch: 193 | T_Loss 0.238 | T_Acc 0.917 | V_Loss 0.623 | V_Acc 0.825 | 3.899
# Epoch: 192 | T_Loss 0.295 | T_Acc 0.892 | V_Loss 0.583 | V_Acc 0.825 | 4.019
# Epoch: 191 | T_Loss 0.358 | T_Acc 0.848 | V_Loss 0.617 | V_Acc 0.763 | 3.664
# Epoch: 190 | T_Loss 0.327 | T_Acc 0.875 | V_Loss 0.751 | V_Acc 0.713 | 3.719
# Epoch: 189 | T_Loss 0.361 | T_Acc 0.863 | V_Loss 0.564 | V_Acc 0.788 | 3.631
# Epoch: 188 | T_Loss 0.293 | T_Acc 0.886 | V_Loss  0.64 | V_Acc 0.813 | 3.799
# Epoch: 187 | T_Loss 0.284 | T_Acc 0.895 | V_Loss 0.659 | V_Acc 0.775 | 3.762
# Epoch: 186 | T_Loss 0.266 | T_Acc 0.908 | V_Loss   0.7 | V_Acc  0.75 | 4.024
# Epoch: 185 | T_Loss 0.286 | T_Acc 0.894 | V_Loss 0.718 | V_Acc 0.737 | 3.785
# Epoch: 184 | T_Loss 0.329 | T_Acc  0.87 | V_Loss 0.579 | V_Acc 0.763 | 3.888
# Epoch: 183 | T_Loss 0.312 | T_Acc 0.887 | V_Loss 0.614 | V_Acc 0.763 | 3.777
# Epoch: 182 | T_Loss 0.347 | T_Acc 0.867 | V_Loss 0.594 | V_Acc 0.763 | 3.798
# Epoch: 181 | T_Loss 0.314 | T_Acc 0.894 | V_Loss 0.633 | V_Acc  0.75 | 3.898
# Epoch: 180 | T_Loss 0.313 | T_Acc 0.878 | V_Loss 0.822 | V_Acc 0.675 | 3.833
# Epoch: 179 | T_Loss 0.283 | T_Acc 0.906 | V_Loss 0.795 | V_Acc 0.688 | 3.801
# Epoch: 178 | T_Loss 0.286 | T_Acc 0.903 | V_Loss 0.696 | V_Acc 0.788 | 3.783
# Epoch: 177 | T_Loss 0.287 | T_Acc 0.902 | V_Loss 0.702 | V_Acc  0.75 | 3.828
# Epoch: 176 | T_Loss 0.297 | T_Acc 0.894 | V_Loss 0.665 | V_Acc 0.763 | 3.794
# Epoch: 175 | T_Loss   0.3 | T_Acc 0.881 | V_Loss 0.692 | V_Acc 0.712 |  3.85
# Epoch: 174 | T_Loss 0.317 | T_Acc  0.88 | V_Loss 0.587 | V_Acc  0.75 | 3.853
# Epoch: 173 | T_Loss 0.339 | T_Acc 0.872 | V_Loss 0.564 | V_Acc  0.75 | 3.736
# Epoch: 172 | T_Loss 0.385 | T_Acc 0.845 | V_Loss 0.542 | V_Acc 0.763 |  3.74
# Epoch: 171 | T_Loss 0.425 | T_Acc 0.809 | V_Loss 0.556 | V_Acc  0.75 | 3.745
# Epoch: 170 | T_Loss 0.513 | T_Acc 0.745 | V_Loss 0.653 | V_Acc  0.65 | 3.761
# Epoch: 169 | T_Loss 0.458 | T_Acc 0.806 | V_Loss 0.549 | V_Acc 0.675 | 3.752
# Epoch: 168 | T_Loss 0.315 | T_Acc  0.87 | V_Loss 0.579 | V_Acc  0.75 | 3.904
# Epoch: 167 | T_Loss 0.335 | T_Acc 0.864 | V_Loss 0.633 | V_Acc   0.7 | 3.896
# Epoch: 166 | T_Loss 0.284 | T_Acc 0.891 | V_Loss 0.598 | V_Acc 0.737 | 3.781
# Epoch: 165 | T_Loss 0.316 | T_Acc 0.878 | V_Loss 0.637 | V_Acc 0.713 | 3.703
# Epoch: 164 | T_Loss 0.331 | T_Acc 0.861 | V_Loss 0.608 | V_Acc 0.738 | 3.746
# Epoch: 163 | T_Loss 0.294 | T_Acc 0.886 | V_Loss 0.676 | V_Acc 0.712 | 3.922
# Epoch: 162 | T_Loss 0.333 | T_Acc 0.859 | V_Loss 0.668 | V_Acc   0.7 | 3.726
# Epoch: 161 | T_Loss 0.327 | T_Acc 0.864 | V_Loss 0.672 | V_Acc   0.7 | 3.789
# Epoch: 160 | T_Loss 0.386 | T_Acc 0.838 | V_Loss   0.6 | V_Acc 0.725 | 3.838
# Epoch: 159 | T_Loss 0.321 | T_Acc 0.872 | V_Loss 0.554 | V_Acc 0.762 | 3.964
# Epoch: 158 | T_Loss 0.325 | T_Acc 0.875 | V_Loss   0.7 | V_Acc 0.675 |  3.91
# Epoch: 157 | T_Loss 0.316 | T_Acc 0.881 | V_Loss  0.64 | V_Acc   0.7 |  3.93
# Epoch: 156 | T_Loss 0.329 | T_Acc 0.877 | V_Loss 0.767 | V_Acc 0.675 | 3.637
# Epoch: 155 | T_Loss 0.324 | T_Acc 0.875 | V_Loss 0.695 | V_Acc 0.675 | 3.692
# Epoch: 154 | T_Loss 0.317 | T_Acc 0.881 | V_Loss 0.608 | V_Acc 0.737 | 3.785
# Epoch: 153 | T_Loss 0.334 | T_Acc 0.878 | V_Loss 0.608 | V_Acc 0.712 | 3.713
# Epoch: 152 | T_Loss 0.333 | T_Acc 0.864 | V_Loss 0.638 | V_Acc 0.713 | 3.634
# Epoch: 151 | T_Loss 0.364 | T_Acc 0.856 | V_Loss 0.527 | V_Acc 0.712 | 3.835
# Epoch: 150 | T_Loss  0.39 | T_Acc 0.842 | V_Loss 0.559 | V_Acc 0.737 | 3.855
# Epoch: 149 | T_Loss 0.371 | T_Acc 0.853 | V_Loss   0.6 | V_Acc 0.725 | 3.698
# Epoch: 148 | T_Loss 0.342 | T_Acc 0.866 | V_Loss 0.777 | V_Acc 0.675 | 3.611
# Epoch: 147 | T_Loss 0.348 | T_Acc 0.859 | V_Loss 0.744 | V_Acc 0.675 | 3.779
# Epoch: 146 | T_Loss 0.373 | T_Acc 0.838 | V_Loss 0.682 | V_Acc 0.688 | 3.692
# Epoch: 145 | T_Loss  0.37 | T_Acc 0.855 | V_Loss 0.663 | V_Acc 0.688 | 3.811
# Epoch: 144 | T_Loss 0.402 | T_Acc 0.836 | V_Loss 0.637 | V_Acc   0.7 | 3.846
# Epoch: 143 | T_Loss 0.412 | T_Acc 0.833 | V_Loss 0.618 | V_Acc 0.712 | 3.736
# Epoch: 142 | T_Loss 0.431 | T_Acc 0.825 | V_Loss 0.585 | V_Acc  0.75 | 3.604
# Epoch: 141 | T_Loss 0.482 | T_Acc 0.789 | V_Loss 0.473 | V_Acc 0.788 | 3.817
# Epoch: 140 | T_Loss 0.383 | T_Acc 0.839 | V_Loss 0.638 | V_Acc 0.662 | 3.858
# Epoch: 139 | T_Loss 0.373 | T_Acc 0.848 | V_Loss 0.832 | V_Acc   0.6 | 4.005
# Epoch: 138 | T_Loss 0.353 | T_Acc 0.862 | V_Loss 0.615 | V_Acc  0.75 |  3.75
# Epoch: 137 | T_Loss  0.35 | T_Acc 0.861 | V_Loss 0.637 | V_Acc 0.725 | 4.052
# Epoch: 136 | T_Loss 0.375 | T_Acc 0.853 | V_Loss 0.589 | V_Acc 0.725 | 3.791
# Epoch: 135 | T_Loss  0.39 | T_Acc  0.82 | V_Loss 0.564 | V_Acc  0.75 | 3.915
# Epoch: 134 | T_Loss 0.335 | T_Acc 0.869 | V_Loss 0.569 | V_Acc  0.75 | 4.211
# Epoch: 133 | T_Loss 0.375 | T_Acc 0.856 | V_Loss 0.597 | V_Acc 0.725 | 4.438
# Epoch: 132 | T_Loss  0.35 | T_Acc 0.863 | V_Loss 0.601 | V_Acc 0.712 | 4.491
# Epoch: 131 | T_Loss 0.368 | T_Acc  0.85 | V_Loss 0.558 | V_Acc 0.763 | 4.213
# Epoch: 130 | T_Loss 0.371 | T_Acc  0.85 | V_Loss 0.649 | V_Acc 0.725 | 4.219
# Epoch: 129 | T_Loss 0.356 | T_Acc 0.859 | V_Loss 0.663 | V_Acc 0.725 | 4.309
# Epoch: 128 | T_Loss 0.389 | T_Acc 0.833 | V_Loss 0.609 | V_Acc 0.737 | 3.632
# Epoch: 127 | T_Loss 0.382 | T_Acc 0.848 | V_Loss 0.612 | V_Acc   0.7 | 3.452
# Epoch: 126 | T_Loss 0.374 | T_Acc 0.839 | V_Loss 0.548 | V_Acc 0.725 | 3.844
# Epoch: 125 | T_Loss 0.429 | T_Acc 0.813 | V_Loss 0.559 | V_Acc 0.738 | 3.798
# Epoch: 124 | T_Loss 0.388 | T_Acc 0.847 | V_Loss 0.565 | V_Acc 0.737 | 3.586
# Epoch: 123 | T_Loss 0.372 | T_Acc 0.844 | V_Loss 0.629 | V_Acc   0.7 |  3.81
# Epoch: 122 | T_Loss 0.396 | T_Acc 0.834 | V_Loss 0.548 | V_Acc 0.737 |  3.75
# Epoch: 121 | T_Loss 0.374 | T_Acc 0.845 | V_Loss 0.611 | V_Acc 0.713 | 3.635
# Epoch: 120 | T_Loss 0.372 | T_Acc 0.847 | V_Loss 0.634 | V_Acc 0.712 | 3.613
# Epoch: 119 | T_Loss 0.381 | T_Acc 0.852 | V_Loss 0.638 | V_Acc   0.7 | 3.853
# Epoch: 118 | T_Loss  0.39 | T_Acc 0.844 | V_Loss 0.602 | V_Acc   0.7 | 3.854
# Epoch: 117 | T_Loss 0.395 | T_Acc 0.839 | V_Loss 0.519 | V_Acc  0.75 | 3.855
# Epoch: 116 | T_Loss 0.375 | T_Acc 0.853 | V_Loss 0.639 | V_Acc 0.725 | 3.862
# Epoch: 115 | T_Loss 0.408 | T_Acc 0.844 | V_Loss 0.611 | V_Acc  0.65 |  3.73
# Epoch: 114 | T_Loss 0.407 | T_Acc 0.823 | V_Loss   0.6 | V_Acc 0.725 | 3.704
# Epoch: 113 | T_Loss 0.393 | T_Acc 0.834 | V_Loss 0.581 | V_Acc 0.725 | 3.697
# Epoch: 112 | T_Loss 0.391 | T_Acc 0.838 | V_Loss 0.561 | V_Acc 0.737 | 3.504
# Epoch: 111 | T_Loss 0.399 | T_Acc 0.833 | V_Loss 0.537 | V_Acc 0.737 | 3.648
# Epoch: 110 | T_Loss 0.399 | T_Acc  0.83 | V_Loss 0.583 | V_Acc   0.7 | 3.481
# Epoch: 109 | T_Loss 0.395 | T_Acc 0.834 | V_Loss 0.603 | V_Acc 0.713 | 3.779
# Epoch: 108 | T_Loss   0.4 | T_Acc 0.838 | V_Loss 0.592 | V_Acc   0.7 | 3.612
# Epoch: 107 | T_Loss 0.418 | T_Acc 0.817 | V_Loss 0.608 | V_Acc 0.688 | 3.691
# Epoch: 106 | T_Loss 0.414 | T_Acc 0.817 | V_Loss 0.601 | V_Acc 0.688 |  3.72
# Epoch: 105 | T_Loss 0.414 | T_Acc 0.823 | V_Loss 0.583 | V_Acc   0.7 | 3.502
# Epoch: 104 | T_Loss  0.41 | T_Acc 0.836 | V_Loss 0.649 | V_Acc 0.675 | 3.663
# Epoch: 103 | T_Loss  0.42 | T_Acc 0.816 | V_Loss 0.578 | V_Acc  0.75 | 3.754
# Epoch: 102 | T_Loss 0.419 | T_Acc 0.823 | V_Loss 0.621 | V_Acc 0.675 | 3.587
# Epoch: 101 | T_Loss 0.436 | T_Acc 0.814 | V_Loss 0.586 | V_Acc 0.688 | 3.575
# Epoch: 100 | T_Loss 0.455 | T_Acc 0.803 | V_Loss 0.595 | V_Acc   0.7 | 3.451
# Epoch:  99 | T_Loss 0.493 | T_Acc 0.761 | V_Loss 0.607 | V_Acc 0.663 | 3.541
# Epoch:  98 | T_Loss 0.548 | T_Acc 0.761 | V_Loss   0.6 | V_Acc 0.662 | 3.714
# Epoch:  97 | T_Loss 0.417 | T_Acc 0.811 | V_Loss 0.618 | V_Acc 0.675 | 3.484
# Epoch:  96 | T_Loss 0.443 | T_Acc 0.811 | V_Loss 0.526 | V_Acc 0.775 | 3.538
# Epoch:  95 | T_Loss 0.501 | T_Acc 0.766 | V_Loss 0.523 | V_Acc 0.737 | 3.531
# Epoch:  94 | T_Loss 0.437 | T_Acc   0.8 | V_Loss 0.598 | V_Acc 0.688 | 3.488
# Epoch:  93 | T_Loss 0.401 | T_Acc 0.817 | V_Loss 0.626 | V_Acc 0.625 | 3.685
# Epoch:  92 | T_Loss 0.418 | T_Acc 0.813 | V_Loss 0.606 | V_Acc 0.662 | 3.697
# Epoch:  91 | T_Loss 0.415 | T_Acc 0.819 | V_Loss 0.538 | V_Acc 0.737 | 3.496
# Epoch:  90 | T_Loss 0.437 | T_Acc 0.805 | V_Loss 0.512 | V_Acc 0.775 | 3.715
# Epoch:  89 | T_Loss 0.473 | T_Acc  0.78 | V_Loss 0.581 | V_Acc 0.687 | 3.688
# Epoch:  88 | T_Loss 0.486 | T_Acc 0.766 | V_Loss 0.708 | V_Acc 0.613 | 3.596
# Epoch:  87 | T_Loss 0.423 | T_Acc 0.823 | V_Loss 0.521 | V_Acc 0.787 | 3.485
# Epoch:  86 | T_Loss 0.414 | T_Acc 0.831 | V_Loss  0.57 | V_Acc 0.762 | 3.744
# Epoch:  85 | T_Loss 0.426 | T_Acc 0.827 | V_Loss 0.551 | V_Acc 0.762 | 3.632
# Epoch:  84 | T_Loss 0.419 | T_Acc 0.822 | V_Loss 0.587 | V_Acc 0.725 | 3.717
# Epoch:  83 | T_Loss 0.435 | T_Acc 0.805 | V_Loss  0.58 | V_Acc   0.7 | 3.568
# Epoch:  82 | T_Loss 0.444 | T_Acc 0.797 | V_Loss 0.627 | V_Acc 0.662 | 3.966
# Epoch:  81 | T_Loss 0.449 | T_Acc 0.802 | V_Loss 0.656 | V_Acc 0.687 | 3.858
# Epoch:  80 | T_Loss 0.447 | T_Acc 0.811 | V_Loss  0.49 | V_Acc   0.8 | 3.783
# Epoch:  79 | T_Loss 0.441 | T_Acc 0.805 | V_Loss 0.627 | V_Acc  0.65 | 4.152
# Epoch:  78 | T_Loss 0.452 | T_Acc 0.792 | V_Loss 0.552 | V_Acc 0.737 | 3.714
# Epoch:  77 | T_Loss 0.452 | T_Acc 0.806 | V_Loss 0.565 | V_Acc 0.713 |  3.83
# Epoch:  76 | T_Loss 0.453 | T_Acc 0.795 | V_Loss 0.465 | V_Acc  0.85 | 4.227
# Epoch:  75 | T_Loss  0.46 | T_Acc 0.791 | V_Loss 0.541 | V_Acc 0.737 |  4.02
# Epoch:  74 | T_Loss 0.484 | T_Acc 0.775 | V_Loss 0.625 | V_Acc   0.7 | 3.933
# Epoch:  73 | T_Loss 0.472 | T_Acc 0.775 | V_Loss 0.663 | V_Acc  0.65 | 4.032
# Epoch:  72 | T_Loss 0.477 | T_Acc 0.781 | V_Loss  0.53 | V_Acc 0.763 | 4.083
# Epoch:  71 | T_Loss 0.498 | T_Acc 0.772 | V_Loss   0.5 | V_Acc 0.775 | 3.856
# Epoch:  70 | T_Loss 0.474 | T_Acc 0.783 | V_Loss 0.585 | V_Acc 0.675 | 3.705
# Epoch:  69 | T_Loss 0.467 | T_Acc 0.783 | V_Loss 0.507 | V_Acc 0.788 | 3.876
# Epoch:  68 | T_Loss 0.471 | T_Acc  0.78 | V_Loss 0.617 | V_Acc 0.688 | 3.867
# Epoch:  67 | T_Loss  0.48 | T_Acc 0.781 | V_Loss 0.578 | V_Acc   0.7 | 3.563
# Epoch:  66 | T_Loss 0.489 | T_Acc 0.777 | V_Loss 0.607 | V_Acc 0.712 | 3.625
# Epoch:  65 | T_Loss 0.492 | T_Acc 0.761 | V_Loss 0.603 | V_Acc 0.663 | 3.585
# Epoch:  64 | T_Loss 0.489 | T_Acc  0.78 | V_Loss 0.565 | V_Acc 0.737 | 3.247
# Epoch:  63 | T_Loss 0.477 | T_Acc 0.778 | V_Loss 0.523 | V_Acc 0.725 |  3.48
# Epoch:  62 | T_Loss 0.478 | T_Acc 0.787 | V_Loss 0.565 | V_Acc 0.725 | 3.316
# Epoch:  61 | T_Loss 0.484 | T_Acc 0.781 | V_Loss 0.565 | V_Acc   0.7 | 3.336
# Epoch:  60 | T_Loss 0.506 | T_Acc 0.756 | V_Loss 0.652 | V_Acc 0.662 | 3.445
# Epoch:  59 | T_Loss 0.493 | T_Acc 0.761 | V_Loss   0.7 | V_Acc 0.625 | 3.288
# Epoch:  58 | T_Loss  0.49 | T_Acc 0.767 | V_Loss  0.57 | V_Acc 0.725 | 2.899
# Epoch:  57 | T_Loss 0.511 | T_Acc 0.744 | V_Loss 0.657 | V_Acc 0.625 | 3.077
# Epoch:  56 | T_Loss 0.496 | T_Acc 0.764 | V_Loss 0.537 | V_Acc 0.738 | 3.072
# Epoch:  55 | T_Loss 0.497 | T_Acc 0.767 | V_Loss 0.535 | V_Acc 0.737 | 2.849
# Epoch:  54 | T_Loss 0.511 | T_Acc 0.761 | V_Loss 0.545 | V_Acc 0.725 | 2.783
# Epoch:  53 | T_Loss 0.522 | T_Acc 0.756 | V_Loss 0.534 | V_Acc 0.737 | 2.789
# Epoch:  52 | T_Loss 0.519 | T_Acc 0.766 | V_Loss 0.529 | V_Acc 0.762 | 2.849
# Epoch:  51 | T_Loss 0.518 | T_Acc 0.773 | V_Loss 0.548 | V_Acc 0.737 | 2.732
# Epoch:  50 | T_Loss 0.525 | T_Acc 0.758 | V_Loss 0.538 | V_Acc 0.775 | 2.851
# Epoch:  49 | T_Loss  0.52 | T_Acc 0.773 | V_Loss 0.658 | V_Acc 0.638 | 2.814
# Epoch:  48 | T_Loss 0.535 | T_Acc 0.748 | V_Loss  0.57 | V_Acc 0.725 | 2.795
# Epoch:  47 | T_Loss 0.529 | T_Acc 0.761 | V_Loss 0.553 | V_Acc 0.712 | 2.815
# Epoch:  46 | T_Loss 0.534 | T_Acc 0.767 | V_Loss 0.553 | V_Acc 0.737 | 2.626
# Epoch:  45 | T_Loss 0.529 | T_Acc  0.77 | V_Loss 0.571 | V_Acc   0.7 |  2.64
# Epoch:  44 | T_Loss 0.531 | T_Acc 0.769 | V_Loss 0.575 | V_Acc 0.687 | 2.699
# Epoch:  43 | T_Loss 0.533 | T_Acc 0.767 | V_Loss 0.602 | V_Acc   0.7 | 2.839
# Epoch:  42 | T_Loss 0.536 | T_Acc 0.761 | V_Loss 0.626 | V_Acc 0.662 | 2.667
# Epoch:  41 | T_Loss  0.54 | T_Acc  0.75 | V_Loss  0.64 | V_Acc  0.65 |  2.76
# Epoch:  40 | T_Loss 0.542 | T_Acc 0.752 | V_Loss 0.638 | V_Acc 0.638 | 2.691
# Epoch:  39 | T_Loss 0.539 | T_Acc 0.753 | V_Loss  0.61 | V_Acc 0.675 | 2.928
# Epoch:  38 | T_Loss 0.547 | T_Acc 0.755 | V_Loss  0.58 | V_Acc 0.675 | 2.681
# Epoch:  37 | T_Loss 0.552 | T_Acc  0.75 | V_Loss 0.592 | V_Acc 0.675 | 2.711
# Epoch:  36 | T_Loss 0.567 | T_Acc 0.731 | V_Loss 0.585 | V_Acc   0.7 | 3.206
# Epoch:  35 | T_Loss 0.571 | T_Acc 0.723 | V_Loss 0.568 | V_Acc 0.712 | 3.348
# Epoch:  34 | T_Loss 0.575 | T_Acc 0.717 | V_Loss 0.556 | V_Acc 0.737 | 2.891
# Epoch:  33 | T_Loss 0.582 | T_Acc 0.719 | V_Loss 0.575 | V_Acc 0.712 | 2.738
# Epoch:  32 | T_Loss 0.586 | T_Acc 0.717 | V_Loss 0.595 | V_Acc   0.7 | 2.662
# Epoch:  31 | T_Loss 0.581 | T_Acc 0.728 | V_Loss 0.609 | V_Acc   0.7 | 2.741
# Epoch:  30 | T_Loss 0.563 | T_Acc 0.737 | V_Loss 0.636 | V_Acc 0.662 | 2.707
# Epoch:  29 | T_Loss  0.57 | T_Acc 0.734 | V_Loss  0.65 | V_Acc 0.638 | 2.671
# Epoch:  28 | T_Loss 0.584 | T_Acc 0.722 | V_Loss 0.632 | V_Acc 0.675 | 2.624
# Epoch:  27 | T_Loss 0.606 | T_Acc 0.691 | V_Loss 0.619 | V_Acc 0.675 | 2.828
# Epoch:  26 | T_Loss 0.606 | T_Acc 0.695 | V_Loss 0.641 | V_Acc 0.625 | 2.792
# Epoch:  25 | T_Loss 0.617 | T_Acc 0.678 | V_Loss 0.662 | V_Acc 0.612 | 2.837
# Epoch:  24 | T_Loss  0.63 | T_Acc 0.666 | V_Loss 0.689 | V_Acc 0.575 | 2.879
# Epoch:  23 | T_Loss 0.634 | T_Acc 0.661 | V_Loss 0.691 | V_Acc 0.587 | 2.676
# Epoch:  22 | T_Loss 0.642 | T_Acc 0.655 | V_Loss 0.706 | V_Acc  0.55 | 2.622
# Epoch:  21 | T_Loss 0.625 | T_Acc 0.667 | V_Loss 0.675 | V_Acc 0.575 | 2.639
# Epoch:  20 | T_Loss 0.632 | T_Acc 0.667 | V_Loss 0.654 | V_Acc 0.612 | 2.665
# Epoch:  19 | T_Loss 0.639 | T_Acc 0.653 | V_Loss 0.641 | V_Acc 0.625 | 2.927
# Epoch:  18 | T_Loss 0.661 | T_Acc 0.638 | V_Loss 0.663 | V_Acc 0.587 | 2.816
# Epoch:  17 | T_Loss  0.68 | T_Acc 0.583 | V_Loss  0.63 | V_Acc 0.612 | 2.736
# Epoch:  16 | T_Loss 0.641 | T_Acc 0.653 | V_Loss 0.671 | V_Acc 0.575 |  2.68
# Epoch:  15 | T_Loss 0.658 | T_Acc 0.636 | V_Loss 0.704 | V_Acc 0.587 | 3.042
# Epoch:  14 | T_Loss 0.665 | T_Acc 0.611 | V_Loss 0.688 | V_Acc 0.563 | 2.735
# Epoch:  13 | T_Loss  0.68 | T_Acc 0.583 | V_Loss 0.666 | V_Acc  0.65 | 3.112
# Epoch:  12 | T_Loss 0.671 | T_Acc 0.608 | V_Loss 0.646 | V_Acc 0.662 | 2.771
# Epoch:  11 | T_Loss 0.684 | T_Acc 0.559 | V_Loss  0.67 | V_Acc 0.675 |  2.69
# Epoch:  10 | T_Loss  0.69 | T_Acc 0.525 | V_Loss 0.689 | V_Acc  0.45 | 2.915
# Epoch:   9 | T_Loss 0.692 | T_Acc 0.508 | V_Loss 0.692 | V_Acc 0.425 | 2.987
# Epoch:   8 | T_Loss 0.692 | T_Acc 0.513 | V_Loss 0.695 | V_Acc 0.375 | 3.013
# Epoch:   7 | T_Loss 0.693 | T_Acc 0.511 | V_Loss 0.697 | V_Acc 0.375 | 2.693
# Epoch:   6 | T_Loss 0.693 | T_Acc 0.511 | V_Loss 0.697 | V_Acc 0.375 | 2.591
# Epoch:   5 | T_Loss 0.693 | T_Acc 0.511 | V_Loss 0.696 | V_Acc 0.375 | 2.872
# Epoch:   4 | T_Loss 0.693 | T_Acc 0.513 | V_Loss 0.696 | V_Acc 0.375 | 2.652
# Epoch:   3 | T_Loss 0.694 | T_Acc 0.497 | V_Loss 0.694 | V_Acc 0.375 |  3.02
# Epoch:   2 | T_Loss 0.694 | T_Acc 0.489 | V_Loss 0.691 | V_Acc 0.625 | 2.852
# Epoch:   1 | T_Loss 0.695 | T_Acc 0.489 | V_Loss 0.686 | V_Acc 0.625 | 2.696
